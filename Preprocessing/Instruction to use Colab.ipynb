# %% [markdown]
# # About this Colab
#
# Colab is a working space that we can code on the python notebook file (.ipynb) remotely. Currently Colab is hosted on Nichy's Google drive. You are allowed to create your python notebook files for testing under **CS4248 Project** directory, but don't forget to write your name.
#
# In the end, we will consolidate each member's codes into a single file, let's call it a main file. There might be some conflicts if multiple users access and run the same Colab at the same time. Thus, when you want to consolidate your work to the main file, please at least notify others in the Telegram group.

# %% [markdown]
# # Input files
#
# Two files of dataset are on Nichy's Google drive: **Restaurants_Train.xml** and **Restaurants_Test.xml**. To load data from these files, you need to copy the code below and paste it in your testing Colab file. There will be a pop up asking you to allow the access, just do it!

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Now we will list all files in Google drive. You will find that the list of documents are from **YOUR** Google drive, not Nichy's Google drive. This is the default setting of Colab.
#
# For simplicity, you can copy **Restaurants_Train.xml** and **Restaurants_Test.xml** and paste them on **YOUR** Google drive. That's going to work fine without any issue even though your Colab testing file is on Nichy's drive and input files is on your own Google drive which is the different location.

# %%
# !ls /content/gdrive/MyDrive

# %% [markdown]
# You can set the path to load input files from your Google drive

# %%
path = '/content/gdrive/MyDrive/Folder1/Folder2/Restaurants_Train.xml'

# %% [markdown]
# If you want to load input files from Nichy's Google drive, choose **CS4248 NLP Project** that Nichy has already shared and **Add a shortcut to Drive**. Then your own Google drive will automatically create another shortcut directory.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When you are working on a Colab testing file, Colab will directly connect to Nichy's Google drive and load the input files for you. With this approach, you don't need to add xml files in your Google drive.

# %%
path = '/content/gdrive/MyDrive/CS4248 NLP Project'
